# %% [markdown]
# # solution 1st

# %%
import thinkdsp as d
from IPython.display import Audio
import thinkplot as t
from IPython.display import Audio
m=d.SinSignal(freq=523,amp=3,offset= 0)
n=d.SinSignal(freq=554,amp=3,offset=0)
o=d.SinSignal(freq=587,amp=4,offset=0)
p=d.SinSignal(freq=622,amp=5,offset=0)
q=d.SinSignal(freq=659,amp=5,offset=0)
r=d.SinSignal(freq=698,amp=5,offset=0)
s=d.SinSignal(freq=740,amp=5,offset=0)
t=d.SinSignal(freq=780,amp=5,offset=0)
u=d.SinSignal(freq=831,amp=5,offset=0)
v=d.SinSignal(freq=880,amp=5,offset=0)
w=d.SinSignal(freq=932,amp=5,offset=0)
x=d.SinSignal(freq=988,amp=5,offset=0)
y=d.SinSignal(freq=1047,amp=5,offset=0)
#r0=m+n+o+p
#r.plot()
m1=m.make_wave(duration=0.5,start=0,framerate=48000)
n1=n.make_wave(duration=0.5,start=0.5,framerate=48000)
o1=o.make_wave(duration=0.5,start=1,framerate=48000)
p1=p.make_wave(duration=0.5,start=1.5,framerate=48000)
q1=q.make_wave(duration=0.5,start=2,framerate=48000)
r1=r.make_wave(duration=0.5,start=2.5,framerate=48000)
s1=s.make_wave(duration=0.5,start=3,framerate=48000)
t1=t.make_wave(duration=0.5,start=3.5,framerate=48000)
u1=u.make_wave(duration=0.5,start=4,framerate=48000)
v1=v.make_wave(duration=0.5,start=4.5,framerate=48000)
w1=w.make_wave(duration=0.5,start=5,framerate=48000)
x1=x.make_wave(duration=0.5,start=5.5,framerate=48000)
y1=y.make_wave(duration=0.5,start=6,framerate=48000)
a= m1+n1+o1+p1+q1+r1+s1+t1+u1+v1+w1+x1+y1
b=Audio(data=a.ys,rate=a.framerate)
b
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # solution 1st

# %%
import thinkdsp as d 
import matplotlib.pyplot as plt
import numpy as n 
import numpy.fft as FFT
import scipy as sp

# %%
m1 = [n.sin(9*n.pi*t) for t in n.linspace(0,2,1000)]
m2 = [n.sin(4*n.pi*t) for t in n.linspace(0,2,1000)]
m3 = [n.sin(9*n.pi*t) for t in n.linspace(0,2,1000)]

# %%
mix = [i+j+k for i,j,k, in zip(m1,m2,m3)]
mix
# Out:
# [0.0,
#  0.13830534375696052,
#  0.27623231322151187,
#  0.4134037052260997,
#  0.5494446551273131,
#  0.6839837967659561,
#  0.8166544112980518,
#  0.9470955612425265,
#  1.0749532061386131,
#  1.1998812962648415,
#  1.3215428409416563,
#  1.4396109480210124,
#  1.5537698312584567,
#  1.6637157823659492,
#  1.7691581046566414,
#  1.8698200053156984,
#  1.9654394434635771,
#  2.0557699313195816,
#  2.1405812859235267,
#  2.21966032903147,
#  2.292811532967241,
#  2.359857610384343,
#  2.4206400460721804,
#  2.4750195691259287,
#  2.52287656399008,
#  2.5641114190811614,
#  2.598644811894749,
#  2.6264179297050054,
#  2.647392625170892,
#  2.6615515063713713,
#  2.6688979610015346,
#  2.6694561146720925,
#  2.6632707234653377,
#  2.6504070011108407,
#  2.6309503813531308,
#  2.6050062162907515,
#  2.572699411670727,
#  2.534174000323921,
#  2.489592655124458,
#  2.439136143049575,
#  2.3830027221044516,
#  2.3214074830590445,
#  2.2545816381202206,
#  2.1827717588319127,
# ...

# %%
fft_wave = FFT.fft(mix)

# %%
plt.plot(mix)

# %% [markdown]
# # solution 4rt

# %%
import thinkdsp as s
import thinkplot as td
from IPython.display import Audio
whistle=s.read_wave("C:/Users/Monu/Downloads/audio.wav")
sp=whistle.make_spectrum()
sp.plot(high=1000)

sp.plot(high=400)
#sp.low_pass(600)
sp.high_pass(100)
aud=sp.make_wave()
aa=aud.make_audio()
aa
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # highpass 2nd music

# %%
import thinkdsp as t
import thinkplot as d
rag = t.read_wave("C:/Users/Monu/Downloads/audio.wav")
rag.plot()
seg = rag.segment(start=0,duration=33)
aud=seg.make_audio()
spec=seg.make_spectrum()
spec.plot(high=1000)
aud
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
